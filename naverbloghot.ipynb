# %%
# %matplotlib notebook
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:/Users/효짜이/Desktop/크롤링 프로젝트/네이버api 이용 블로그조사/상권분석결론자료.csv')
df.head(5)
# Out:
#       place  percentage
# 0   Gangnam          54
# 1    Hyehwa          87
# 2  Shinchon          42
# 3  Seokyeng           8
# 4    kundae          65

# %%
sns.barplot(data=df, x="place", y="percentage")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
