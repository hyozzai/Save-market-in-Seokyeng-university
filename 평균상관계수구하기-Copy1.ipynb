# %%
import numpy as np
import pandas as pd

# %%
average_daehak = pd.read_csv('C:/Users/효짜이/Desktop/crawling/datafile/eachsanggun.csv',encoding='euc-kr')

# %%
average_daehak.head()
# 1을 넣은 이유는 오류가 계속 떠서 그냥 다음칸에 유동인구를 넣었습니다.
# Out:
#    구분        평균매출액   점포  3년유지율  거주인구  직장인구    면적크기       1    유동인구
# 0  홍대  79653653.75  338   50.0    82   292  584088  126339  126339
# 1  건대  92618376.83  117   43.2   209   163   96064  294023  294023
# 2  신촌  58422378.58  202   37.8   106   157  255696  241357  241357
# 3  서경  21453000.17    5   50.0   300    23   98569   19981   19981

# %%
np.corrcoef(average_daehak['평균매출액'],average_daehak['점포'])
# Out:
# array([[1.        , 0.60560847],
#        [0.60560847, 1.        ]])

# %%
np.corrcoef(average_daehak['평균매출액'],average_daehak['3년유지율'])
# Out:
# array([[ 1.        , -0.26264745],
#        [-0.26264745,  1.        ]])

# %%
np.corrcoef(average_daehak['평균매출액'],average_daehak['거주인구'])
# Out:
# array([[ 1.        , -0.57900808],
#        [-0.57900808,  1.        ]])

# %%
np.corrcoef(average_daehak['평균매출액'],average_daehak['직장인구'])
# Out:
# array([[1.        , 0.77983158],
#        [0.77983158, 1.        ]])

# %%
np.corrcoef(average_daehak['평균매출액'],average_daehak['면적크기'])
# Out:
# array([[1.        , 0.33948949],
#        [0.33948949, 1.        ]])

# %%
np.corrcoef(average_daehak['평균매출액'],average_daehak['유동인구'])
# Out:
# array([[1.        , 0.77568324],
#        [0.77568324, 1.        ]])

# %%
import platform
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

# %%
average_daehak['평균매출액'].plot(kind='barh', grid=True, figsize = (10,10))

# %%
average_daehak['점포'].plot(kind='barh', grid=True, figsize = (10,10))

# %%
average_daehak['3년유지율'].plot(kind='barh', grid=True, figsize = (10,10))

# %%
average_daehak['거주인구'].plot(kind='barh', grid=True, figsize = (10,10))

# %%
average_daehak['직장인구'].plot(kind='barh', grid=True, figsize = (10,10))

# %%
average_daehak['면적크기'].plot(kind='barh', grid=True, figsize = (10,10))

# %%
average_daehak['유동인구'].plot(kind='barh', grid=True, figsize = (10,10))

# %%
fp1=np.polyfit(average_daehak['면적크기'],average_daehak['평균매출액'],1)
fp1
# Out:
# array([4.60100676e+01, 5.11384533e+07])

# %%
f1=np.poly1d(fp1)
print(f1)
fx=np.linspace(0,300000,100)
print(fx)
# Out:
#
# 46.01 x + 5.114e+07
# [     0.           3030.3030303    6060.60606061   9090.90909091
#   12121.21212121  15151.51515152  18181.81818182  21212.12121212
#   24242.42424242  27272.72727273  30303.03030303  33333.33333333
#   36363.63636364  39393.93939394  42424.24242424  45454.54545455
#   48484.84848485  51515.15151515  54545.45454545  57575.75757576
#   60606.06060606  63636.36363636  66666.66666667  69696.96969697
#   72727.27272727  75757.57575758  78787.87878788  81818.18181818
#   84848.48484848  87878.78787879  90909.09090909  93939.39393939
#   96969.6969697  100000.         103030.3030303  106060.60606061
#  109090.90909091 112121.21212121 115151.51515152 118181.81818182
#  121212.12121212 124242.42424242 127272.72727273 130303.03030303
#  133333.33333333 136363.63636364 139393.93939394 142424.24242424
#  145454.54545455 148484.84848485 151515.15151515 154545.45454545
#  157575.75757576 160606.06060606 163636.36363636 166666.66666667
#  169696.96969697 172727.27272727 175757.57575758 178787.87878788
#  181818.18181818 184848.48484848 187878.78787879 190909.09090909
#  193939.39393939 196969.6969697  200000.         203030.3030303
#  206060.60606061 209090.90909091 212121.21212121 215151.51515152
#  218181.81818182 221212.12121212 224242.42424242 227272.72727273
#  230303.03030303 233333.33333333 236363.63636364 239393.93939394
#  242424.24242424 245454.54545455 248484.84848485 251515.15151515
#  254545.45454545 257575.75757576 260606.06060606 263636.36363636
#  266666.66666667 269696.96969697 272727.27272727 275757.57575758
#  278787.87878788 281818.18181818 284848.48484848 287878.78787879
#  290909.09090909 293939.39393939 296969.6969697  300000.        ]

# %%
plt.figure(figsize=(10,10))
plt.scatter(average_daehak['평균매출액'],average_daehak['면적크기'], s=50)
plt.plot(fx,f1(fx),ls='dashed', lw=3,color='g')
plt.xlabel('평균매출액')
plt.ylabel('면적크기')
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-07017d5c3606> in <module>
# ----> 1 plt.figure(figsize=(10,10))
#       2 plt.scatter(average_daehak['평균매출액'],average_daehak['면적크기'], s=50)
#       3 plt.plot(fx,f1(fx),ls='dashed', lw=3,color='g')
#       4 plt.xlabel('평균매출액')
#       5 plt.ylabel('면적크기')
#
# NameError: name 'plt' is not defined
