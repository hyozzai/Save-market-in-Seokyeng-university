# %%
import pandas as pd
import numpy as np

# %%
money_daehak = pd.read_csv('./C:/Users/hyozzai/Desktop/crawling/datafile/money.csv', endcoding='euc-kr')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-98fb36b7a1a3> in <module>
# ----> 1 money_daehak = pd.read_csv('./C:/Users/hyozzai/Desktop/crawling/datafile/money.csv', endcoding='euc-kr')
#
# TypeError: parser_f() got an unexpected keyword argument 'endcoding'
